# %% [markdown]
# <a href="https://colab.research.google.com/github/KMVarma/scheduler-3/blob/master/testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import readcsv as course_dictionary
import ipynb.fs.full.scheduler
# Out:
# Traceback (most recent call last):
#
#   File "/Users/Sashank/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-0f0717e396ca>", line 2, in <module>
#     import ipynb.fs.full.scheduler
#
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#
#   File "/Users/Sashank/anaconda3/lib/python3.7/site-packages/ipynb/fs/full/__init__.py", line 43, in get_code
#     return self.source_to_code(code_from_ipynb(nb), self.path)
#
#   File "/Users/Sashank/scheduler-3/scheduler.ipynb", line 10
#     "language_info": {
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Testing Course Dictionary (code from Dr. Fisher)

# %%
test = course_dictionary.create_course_dict()
# Test to see if all prereqs are in the file.
prereq_list = [single_course for vals in test.values()
                for some_prereqs in vals.prereqs for single_course in some_prereqs]
for prereq in prereq_list:
    if prereq not in test:
        print(prereq)
for key in test:
    # Test to see if every course has a term and credits.
    if not test[key].terms or not test[key].credits:
        print(key)
    # Test to see if a course's prereqs include the course itself
    if key in [course for prereq in test[key].prereqs for course in prereq]:
        print(key);
print('Done')
# Out:
# Done

# %%
# Prints all the CS courses.
for key in test:
    if key.program == 'CS':
        print(key, test[key])
# Out:
# Course(program='CS', designation='3860') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=((('CS', '2231'),),))
# Course(program='CS', designation='3861') CourseInfo(credits=3, terms=('Summer', 'Spring', 'Fall'), prereqs=((('CS', '2231'),),))
# Course(program='CS', designation='3892') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='CS', designation='3890') CourseInfo(credits=3, terms=('Summer',), prereqs=())
# Course(program='CS', designation='3891') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='CS', designation='major') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', 'mathematics'), ('CS', 'sciencelab'), ('CS', 'scienceb'), ('CS', 'sciencec'), ('CS', 'esintro'), ('CS', 'liberalarts'), ('CS', 'core'), ('CS', 'depth'), ('CS', '4959'), ('CS', 'techelectives'), ('CS', '1151'), ('CS', 'openelectives'), ('CS', 'writingrequirement')),))
# Course(program='CS', designation='mathematics') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', 'calculus'), ('CS', 'statsprobability'), ('CS', 'mathelective')),))
# Course(program='CS', designation='calculus') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('MATH', '1200'), ('MATH', '1201'), ('MATH', '1301'), ('MATH', '2300'), ('MATH', '2410')), (('MATH', '1200'), ('MATH', '1201'), ('MATH', '1301'), ('MATH', '2300'), ('MATH', '2600')), (('MATH', '1300'), ('MATH', '1301'), ('MATH', '2300'), ('MATH', '2410')), (('MATH', '1300'), ('MATH', '1301'), ('MATH', '2300'), ('MATH', '2600')), (('MATH', '1300'), ('MATH', '1301'), ('MATH', '2500'), ('MATH', '2501'))))
# Course(program='CS', designation='statsprobability') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('MATH', '2810'),), (('MATH', '2820'),), (('MATH', '3640'),)))
# Course(program='CS', designation='mathelective') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('MATH', '2420'),), (('MATH', '2610'),), (('MATH', '2820'),), (('MATH', '3000'),), (('MATH', '3010'),), (('MATH', '3100'),), (('MATH', '3200'),), (('MATH', '3210'),), (('MATH', '3300'),), (('MATH', '3320'),), (('MATH', '3620'),), (('MATH', '3640'),), (('MATH', '3650'),), (('MATH', '3700'),), (('MATH', '3800'),), (('MATH', '3859'),), (('MATH', '4200'),), (('MATH', '4220'),), (('MATH', '4300'),), (('MATH', '4620'),), (('MATH', '4710'),), (('MATH', '2810'),), (('MATH', '2821'),), (('MATH', '3110'),), (('MATH', '3120'),), (('MATH', '3130'),), (('MATH', '3310'),), (('MATH', '3600'),), (('MATH', '3630'),), (('MATH', '3641'),), (('MATH', '3651'),), (('MATH', '3660'),), (('MATH', '4201'),), (('MATH', '4301'),), (('MATH', '4310'),), (('MATH', '4600'),), (('MATH', '4630'),), (('MATH', '4650'),), (('MATH', '4999'),), (('MATH', '4110'),), (('MATH', '3230'),), (('MATH', '4610'),), (('MATH', '4700'),)))
# Course(program='CS', designation='sciencelab') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BSCI', '1100'), ('BSCI', '1100L')), (('BSCI', '1510'), ('BSCI', '1510L')), (('BSCI', '1511'), ('BSCI', '1511L')), (('CHEM', '1601'), ('CHEM', '1601L')), (('CHEM', '1602'), ('CHEM', '1602L')), (('EES', '1510'), ('EES', '1510L')), (('MSE', '1500'), ('MSE', '1500L')), (('PHYS', '1601'), ('PHYS', '1601L')), (('PHYS', '1602'), ('PHYS', '1602L'))))
# Course(program='CS', designation='scienceb') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BSCI', '1100'),), (('BSCI', '1510'),), (('BSCI', '1511'),), (('BSCI', '2218'),), (('BSCI', '2219'),), (('CHEM', '1601'),), (('CHEM', '1602'),), (('EES', '1510'),), (('MSE', '1500'),), (('PHYS', '1601'),), (('PHYS', '1602'),)))
# Course(program='CS', designation='sciencec') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BSCI', '1100'),), (('BSCI', '1510'),), (('BSCI', '1511'),), (('BSCI', '2218'),), (('BSCI', '2219'),), (('CHEM', '1601'),), (('CHEM', '1602'),), (('EES', '1510'),), (('MSE', '1500'),), (('PHYS', '1601'),), (('PHYS', '1602'),)))
# Course(program='CS', designation='liberalarts') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', 'liberalhum'), ('CS', 'liberalsoc'), ('CS', 'liberalother')),))
# Course(program='CS', designation='liberalhum') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('HIST', '2700'), ('ENGL', '3896')), (('ENGL', '1250W'), ('EUS', '2203'))))
# Course(program='CS', designation='liberalsoc') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('PSY', '1200'), ('SOC', '3702')), (('SOC', '3321'), ('ANTH', '4154'))))
# Course(program='CS', designation='liberalother') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('ARTS', '1102'), ('ARTS', '2101')), (('ARTS', '1102'), ('ARTS', '2102'))))
# Course(program='CS', designation='esintro') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('ES', '1401'), ('ES', '1402'), ('ES', '1403')),))
# Course(program='CS', designation='core') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', '1101'), ('CS', '2201'), ('CS', '3251'), ('CS', '3270'), ('EECE', '2116'), ('EECE', '2116L'), ('CS', '2231'), ('CS', '3281'), ('CS', '2212'), ('CS', '3250')),))
# Course(program='CS', designation='depth') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', 'depthproject'), ('CS', 'depthothera'), ('CS', 'depthotherb'), ('CS', 'depthotherc')),))
# Course(program='CS', designation='depthproject') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', '3259'),), (('CS', '3892'),), (('CS', '4269'),), (('CS', '4279'),), (('CS', '4287'),)))
# Course(program='CS', designation='depthothera') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', '3259'),), (('CS', '3282'),), (('CS', '3860'),), (('CS', '3861'),), (('CS', '3892'),), (('CS', '4260'),), (('CS', '4278'),), (('CS', '4285'),), (('CS', '4287'),), (('CS', '4959'),), (('CS', '3252'),), (('CS', '3265'),), (('CS', '3274'),), (('CS', '4269'),), (('CS', '4279'),), (('CS', '4283'),), (('CS', '3890'),), (('CS', '4288'),), (('CS', '3258'),), (('CS', '3276'),), (('CS', '4266'),), (('CS', '3891'),), (('EECE', '4353'),), (('EECE', '4354'),), (('EECE', '4376'),), (('MATH', '3320'),), (('MATH', '3620'),), (('MATH', '4600'),), (('MATH', '4620'),), (('CS', '3860'),), (('CS', '3861'),)))
# Course(program='CS', designation='depthotherb') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', '3259'),), (('CS', '3282'),), (('CS', '3860'),), (('CS', '3861'),), (('CS', '3892'),), (('CS', '4260'),), (('CS', '4278'),), (('CS', '4285'),), (('CS', '4287'),), (('CS', '4959'),), (('CS', '3252'),), (('CS', '3265'),), (('CS', '3274'),), (('CS', '4269'),), (('CS', '4279'),), (('CS', '4283'),), (('CS', '3890'),), (('CS', '4288'),), (('CS', '3258'),), (('CS', '3276'),), (('CS', '4266'),), (('CS', '3891'),), (('EECE', '4353'),), (('EECE', '4354'),), (('EECE', '4376'),), (('MATH', '3320'),), (('MATH', '3620'),), (('MATH', '4600'),), (('MATH', '4620'),), (('CS', '3860'),), (('CS', '3861'),)))
# Course(program='CS', designation='depthotherc') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', '3259'),), (('CS', '3282'),), (('CS', '3860'),), (('CS', '3861'),), (('CS', '3892'),), (('CS', '4260'),), (('CS', '4278'),), (('CS', '4285'),), (('CS', '4287'),), (('CS', '4959'),), (('CS', '3252'),), (('CS', '3265'),), (('CS', '3274'),), (('CS', '4269'),), (('CS', '4279'),), (('CS', '4283'),), (('CS', '3890'),), (('CS', '4288'),), (('CS', '3258'),), (('CS', '3276'),), (('CS', '4266'),), (('CS', '3891'),), (('EECE', '4353'),), (('EECE', '4354'),), (('EECE', '4376'),), (('MATH', '3320'),), (('MATH', '3620'),), (('MATH', '4600'),), (('MATH', '4620'),), (('CS', '3860'),), (('CS', '3861'),)))
# Course(program='CS', designation='writingrequirement') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('AADS', '3104W'),), (('AADS', '3204W'),), (('AADS', '4228W'),), (('AMER', '1002W'),), (('ANTH', '1201W'),), (('ANTH', '2113W'),), (('ANTH', '2220W'),), (('ANTH', '3150W'),), (('ANTH', '3243W'),), (('ANTH', '3622W'),), (('ANTH', '2242W'),), (('ANTH', '1130W'),), (('ASIA', '2609W'),), (('BME', '4900W'),), (('CE', '3100W'),), (('CHBE', '4950W'),), (('CHBE', '3900W'),), (('CHBE', '4951W'),), (('CHEM', '3135W'),), (('CHIN', '3302W'),), (('CHIN', '3302W'),), (('CMA', '1002W'),), (('CMA', '2600W'),), (('CMST', '3620W'),), (('ECON', '4510W'),), (('ECON', '4520W'),), (('ECON', '4530W'),), (('ENGL', '1210W'),), (('ENGL', '1220W'),), (('ENGL', '1230W'),), (('ENGL', '1250W'),), (('ENGL', '1260W'),), (('ENGL', '1270W'),), (('ENGL', '1300W'),), (('ENGL', '2316W'),), (('ENGL', '2318W'),), (('ENGL', '2319W'),), (('ENGL', '3340W'),), (('ENGL', '3890W'),), (('ENGL', '3670W'),), (('ES', '2100W'),), (('FREN', '2501W'),), (('FREN', '2550W'),), (('GER', '2310W'),), (('GER', '3202W'),), (('HART', '2320W'),), (('HART', '1500W'),), (('HART', '3364W'),), (('HART', '3767W'),), (('HART', '3810W'),), (('HART', '3228W'),), (('HART', '1285W'),), (('HART', '1330W'),), (('HART', '3605W'),), (('HART', '1210W'),), (('HART', '3240W'),), (('HART', '3725W'),), (('HIST', '3000W'),), (('HIST', '1385W'),), (('HIST', '1425W'),), (('HIST', '1780W'),), (('HIST', '3045W'),), (('HIST', '3240W'),), (('HIST', '1422W'),), (('HIST', '1582W'),), (('HIST', '1725W'),), (('HIST', '1882W'),), (('HIST', '3220W'),), (('HIST', '1427W'),), (('HIST', '1430W'),), (('HONS', '1810W'),), (('HONS', '1820W'),), (('HONS', '1830W'),), (('HONS', '1850W'),), (('HONS', '1860W'),), (('HONS', '1840W'),), (('ITA', '2501W'),), (('JS', '2230W'),), (('JS', '2290W'),), (('JS', '1002W'),), (('JS', '2240W'),), (('JS', '2250W'),), (('JS', '2420W'),), (('JS', '2280W'),), (('MHS', '3050W'),), (('MUSL', '2200W'),), (('PHIL', '1002W'),), (('PHIL', '1200W'),), (('PHIL', '1008W'),), (('PHIL', '3012W'),), (('PHYS', '2250W'),), (('PHYS', '2260W'),), (('PSCI', '3264W'),), (('PSCI', '3272W'),), (('RLST', '4960W'),), (('RLST', '1190W'),), (('RLST', '2210W'),), (('RLST', '2250W'),), (('RUSS', '1910W'),), (('SOC', '1010W'),), (('SOC', '1020W'),), (('SOC', '1041W'),), (('SOC', '3224W'),), (('SPAN', '3301W'),)))
# Course(program='CS', designation='techelectives') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', 'techelectives1'), ('CS', 'techelectives2')),))
# Course(program='CS', designation='techelectives1') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BME', '2100'),), (('BME', '3000'),), (('BME', '3100'),), (('BME', '3110'),), (('BME', '3200'),), (('BME', '3300'),), (('BME', '3860'),), (('BME', '3861'),), (('BME', '3890'),), (('BME', '4100'),), (('BME', '4200'),), (('BME', '4420'),), (('BME', '4600'),), (('BME', '4900W'),), (('BME', '4950'),), (('BME', '4959'),), (('BME', '2200'),), (('BME', '2210'),), (('BME', '3101'),), (('BME', '3891'),), (('BME', '3892'),), (('BME', '3893'),), (('BME', '4400'),), (('BME', '4500'),), (('BME', '4951'),), (('CE', '2100'),), (('CE', '2200'),), (('CE', '2205'),), (('CE', '3200'),), (('CE', '3250'),), (('CE', '3600'),), (('CE', '3601'),), (('CE', '3700'),), (('CE', '3841'),), (('CE', '3842'),), (('CE', '4200'),), (('CE', '4300'),), (('CE', '4400'),), (('CE', '4405'),), (('CE', '4510'),), (('CE', '4950'),), (('CE', '2105'),), (('CE', '3100W'),), (('CE', '3205'),), (('CE', '3705'),), (('CE', '3843'),), (('CE', '4210'),), (('CE', '4250'),), (('CE', '4420'),), (('CE', '4425'),), (('CE', '4430'),), (('CE', '4500'),), (('CE', '4900'),), (('CE', '4951'),), (('CE', '4415'),), (('CE', '3501'),), (('CE', '3890'),), (('CE', '4410'),), (('CE', '2101'),), (('CE', '2120'),), (('CE', '4401'),), (('CE', '4959'),), (('CHBE', '2100'),), (('CHBE', '2150'),), (('CHBE', '3200'),), (('CHBE', '3300'),), (('CHBE', '3860'),), (('CHBE', '3861'),), (('CHBE', '3890'),), (('CHBE', '4500'),), (('CHBE', '4870'),), (('CHBE', '4900W'),), (('CHBE', '4950W'),), (('CHBE', '4959'),), (('CHBE', '2200'),), (('CHBE', '2250'),), (('CHBE', '3250'),), (('CHBE', '3350'),), (('CHBE', '3600'),), (('CHBE', '3900W'),), (('CHBE', '4820'),), (('CHBE', '4860'),), (('CHBE', '4880'),), (('CHBE', '4951W'),), (('CHBE', '4810'),), (('CHBE', '4840'),), (('CHBE', '4830'),), (('CHBE', '4850'),), (('CS', '3259'),), (('CS', '3282'),), (('CS', '3860'),), (('CS', '3861'),), (('CS', '3892'),), (('CS', '4260'),), (('CS', '4278'),), (('CS', '4285'),), (('CS', '4287'),), (('CS', '4959'),), (('CS', '3252'),), (('CS', '3265'),), (('CS', '3274'),), (('CS', '4269'),), (('CS', '4279'),), (('CS', '4283'),), (('CS', '3890'),), (('CS', '4288'),), (('CS', '3258'),), (('CS', '3276'),), (('CS', '4266'),), (('CS', '3891'),), (('EECE', '2112'),), (('EECE', '2213'),), (('EECE', '3214'),), (('EECE', '3233'),), (('EECE', '3235'),), (('EECE', '3850'),), (('EECE', '3851'),), (('EECE', '4257'),), (('EECE', '4283'),), (('EECE', '4286'),), (('EECE', '4353'),), (('EECE', '4354'),), (('EECE', '4371'),), (('EECE', '4376'),), (('EECE', '4385'),), (('EECE', '4950'),), (('EECE', '4959'),), (('EECE', '2218'),), (('EECE', '3892'),), (('EECE', '4252'),), (('EECE', '4275'),), (('EECE', '4284'),), (('EECE', '4356'),), (('EECE', '4358'),), (('EECE', '4377'),), (('EECE', '4380'),), (('EECE', '4951'),), (('EECE', '3891'),), (('EECE', '4267'),), (('EECE', '4288'),), (('ME', '2160'),), (('ME', '2220'),), (('ME', '3202'),), (('ME', '3224'),), (('ME', '3234'),), (('ME', '3841'),), (('ME', '3860'),), (('ME', '3890'),), (('ME', '4213'),), (('ME', '4236'),), (('ME', '4251'),), (('ME', '4265'),), (('ME', '4271'),), (('ME', '4950'),), (('ME', '4959'),), (('ME', '2171'),), (('ME', '2190'),), (('ME', '3204'),), (('ME', '3248'),), (('ME', '3842'),), (('ME', '4258'),), (('ME', '4261'),), (('ME', '4262'),), (('ME', '4263'),), (('ME', '4267'),), (('ME', '4280'),), (('ME', '4951'),), (('ME', '4264'),), (('ME', '4284'),), (('ME', '4275'),), (('MATH', '2600'),), (('MATH', '2610'),), (('MATH', '2820'),), (('MATH', '3000'),), (('MATH', '3010'),), (('MATH', '3100'),), (('MATH', '3200'),), (('MATH', '3210'),), (('MATH', '3300'),), (('MATH', '3320'),), (('MATH', '3620'),), (('MATH', '3640'),), (('MATH', '3650'),), (('MATH', '3700'),), (('MATH', '3800'),), (('MATH', '3859'),), (('MATH', '4200'),), (('MATH', '4220'),), (('MATH', '4300'),), (('MATH', '4620'),), (('MATH', '4710'),), (('MATH', '2501'),), (('MATH', '2810'),), (('MATH', '2821'),), (('MATH', '31 ...
# Course(program='CS', designation='techelectives2') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BME', '2100'),), (('BME', '3000'),), (('BME', '3100'),), (('BME', '3110'),), (('BME', '3200'),), (('BME', '3300'),), (('BME', '3860'),), (('BME', '3861'),), (('BME', '3890'),), (('BME', '4100'),), (('BME', '4200'),), (('BME', '4420'),), (('BME', '4600'),), (('BME', '4900W'),), (('BME', '4950'),), (('BME', '4959'),), (('BME', '2200'),), (('BME', '2210'),), (('BME', '3101'),), (('BME', '3891'),), (('BME', '3892'),), (('BME', '3893'),), (('BME', '4400'),), (('BME', '4500'),), (('BME', '4951'),), (('CE', '2100'),), (('CE', '2200'),), (('CE', '2205'),), (('CE', '3200'),), (('CE', '3250'),), (('CE', '3600'),), (('CE', '3601'),), (('CE', '3700'),), (('CE', '3841'),), (('CE', '3842'),), (('CE', '4200'),), (('CE', '4300'),), (('CE', '4400'),), (('CE', '4405'),), (('CE', '4510'),), (('CE', '4950'),), (('CE', '2105'),), (('CE', '3100W'),), (('CE', '3205'),), (('CE', '3705'),), (('CE', '3843'),), (('CE', '4210'),), (('CE', '4250'),), (('CE', '4420'),), (('CE', '4425'),), (('CE', '4430'),), (('CE', '4500'),), (('CE', '4900'),), (('CE', '4951'),), (('CE', '4415'),), (('CE', '3501'),), (('CE', '3890'),), (('CE', '4410'),), (('CE', '2101'),), (('CE', '2120'),), (('CE', '4401'),), (('CE', '4959'),), (('CHBE', '2100'),), (('CHBE', '2150'),), (('CHBE', '3200'),), (('CHBE', '3300'),), (('CHBE', '3860'),), (('CHBE', '3861'),), (('CHBE', '3890'),), (('CHBE', '4500'),), (('CHBE', '4870'),), (('CHBE', '4900W'),), (('CHBE', '4950W'),), (('CHBE', '4959'),), (('CHBE', '2200'),), (('CHBE', '2250'),), (('CHBE', '3250'),), (('CHBE', '3350'),), (('CHBE', '3600'),), (('CHBE', '3900W'),), (('CHBE', '4820'),), (('CHBE', '4860'),), (('CHBE', '4880'),), (('CHBE', '4951W'),), (('CHBE', '4810'),), (('CHBE', '4840'),), (('CHBE', '4830'),), (('CHBE', '4850'),), (('CS', '3259'),), (('CS', '3282'),), (('CS', '3860'),), (('CS', '3861'),), (('CS', '3892'),), (('CS', '4260'),), (('CS', '4278'),), (('CS', '4285'),), (('CS', '4287'),), (('CS', '4959'),), (('CS', '3252'),), (('CS', '3265'),), (('CS', '3274'),), (('CS', '4269'),), (('CS', '4279'),), (('CS', '4283'),), (('CS', '3890'),), (('CS', '4288'),), (('CS', '3258'),), (('CS', '3276'),), (('CS', '4266'),), (('CS', '3891'),), (('EECE', '2112'),), (('EECE', '2213'),), (('EECE', '3214'),), (('EECE', '3233'),), (('EECE', '3235'),), (('EECE', '3850'),), (('EECE', '3851'),), (('EECE', '4257'),), (('EECE', '4283'),), (('EECE', '4286'),), (('EECE', '4353'),), (('EECE', '4354'),), (('EECE', '4371'),), (('EECE', '4376'),), (('EECE', '4385'),), (('EECE', '4950'),), (('EECE', '4959'),), (('EECE', '2218'),), (('EECE', '3892'),), (('EECE', '4252'),), (('EECE', '4275'),), (('EECE', '4284'),), (('EECE', '4356'),), (('EECE', '4358'),), (('EECE', '4377'),), (('EECE', '4380'),), (('EECE', '4951'),), (('EECE', '3891'),), (('EECE', '4267'),), (('EECE', '4288'),), (('ME', '2160'),), (('ME', '2220'),), (('ME', '3202'),), (('ME', '3224'),), (('ME', '3234'),), (('ME', '3841'),), (('ME', '3860'),), (('ME', '3890'),), (('ME', '4213'),), (('ME', '4236'),), (('ME', '4251'),), (('ME', '4265'),), (('ME', '4271'),), (('ME', '4950'),), (('ME', '4959'),), (('ME', '2171'),), (('ME', '2190'),), (('ME', '3204'),), (('ME', '3248'),), (('ME', '3842'),), (('ME', '4258'),), (('ME', '4261'),), (('ME', '4262'),), (('ME', '4263'),), (('ME', '4267'),), (('ME', '4280'),), (('ME', '4951'),), (('ME', '4264'),), (('ME', '4284'),), (('ME', '4275'),), (('MATH', '2600'),), (('MATH', '2610'),), (('MATH', '2820'),), (('MATH', '3000'),), (('MATH', '3010'),), (('MATH', '3100'),), (('MATH', '3200'),), (('MATH', '3210'),), (('MATH', '3300'),), (('MATH', '3320'),), (('MATH', '3620'),), (('MATH', '3640'),), (('MATH', '3650'),), (('MATH', '3700'),), (('MATH', '3800'),), (('MATH', '3859'),), (('MATH', '4200'),), (('MATH', '4220'),), (('MATH', '4300'),), (('MATH', '4620'),), (('MATH', '4710'),), (('MATH', '2501'),), (('MATH', '2810'),), (('MATH', '2821'),), (('MATH', '31 ...
# Course(program='CS', designation='openelectives') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('CS', 'open1'), ('CS', 'open2'), ('CS', 'open3'), ('CS', 'open4'), ('CS', 'open5'), ('CS', 'open6')),))
# Course(program='CS', designation='open1') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BASS', '1000'),), (('BSSN', '1000'),), (('CLAR', '1000'),), (('CLLO', '1000'),), (('COMP', '1000'),), (('FLUT', '1000'),), (('GTR', '1000'),), (('HARP', '1000'),), (('HORN', '1000'),), (('MUSO', '1000'),), (('OBOE', '1000'),), (('PERC', '1000'),), (('PIAN', '1000'),), (('SAX', '1000'),), (('AADS', '1001'),), (('ANTH', '1001'),), (('ARTS', '1001'),), (('ASTR', '1001'),), (('BSCI', '1001'),), (('CMST', '1001'),), (('EDUC', '1001'),), (('EES', '1001'),), (('ES', '1001'),), (('EUS', '1001'),), (('ITA', '1001'),), (('MGRL', '1001'),), (('MHS', '1001'),), (('MUSO', '1001'),), (('NSC', '1001'),), (('PSCI', '1001'),), (('PSY', '1001'),), (('RLST', '1001'),), (('SOC', '1001'),), (('SPAN', '1001'),), (('SPED', '1001'),), (('AMER', '1002'),), (('CMST', '1002'),), (('PHIL', '1002'),), (('AMER', '1002W'),), (('CMA', '1002W'),), (('JS', '1002W'),), (('PHIL', '1002W'),), (('PHIL', '1003'),), (('MATH', '1005'),), (('PHIL', '1005'),), (('PHIL', '1008'),), (('PHIL', '1008W'),), (('AADS', '1010'),), (('ASTR', '1010'),), (('CHEM', '1010'),), (('CLAS', '1010'),), (('ECON', '1010'),), (('GTR', '1010'),), (('MATH', '1010'),), (('MUED', '1010'),), (('MUSE', '1010'),), (('PERC', '1010'),), (('PHYS', '1010'),), (('PIAN', '1010'),), (('RLST', '1010'),), (('SOC', '1010'),), (('STPN', '1010'),), (('SOC', '1010W'),), (('CHIN', '1011'),), (('JAPN', '1011'),), (('MATH', '1011'),), (('CHIN', '1012'),), (('JAPN', '1012'),), (('AADS', '1016'),), (('CHEM', '1020'),), (('ECON', '1020'),), (('GTR', '1020'),), (('MUED', '1020'),), (('MUSE', '1020'),), (('PIAN', '1020'),), (('SOC', '1020'),), (('ASTR', '1020L'),), (('CHEM', '1020L'),), (('SOC', '1020W'),), (('EES', '1030'),), (('GTR', '1030'),), (('MUED', '1030'),), (('MUSE', '1030'),), (('EES', '1030L'),), (('MUED', '1040'),), (('SOC', '1041'),), (('SOC', '1041W'),), (('MUED', '1050'),), (('HIST', '1060'),), (('MUED', '1060'),), (('HIST', '1070'),), (('MUED', '1070'),), (('EES', '1080'),), (('HIST', '1080'),), (('HIST', '1090'),), (('BASS', '1100'),), (('BNJO', '1100'),), (('BRQ', '1100'),), (('BSCI', '1100'),), (('BSSN', '1100'),), (('CLAR', '1100'),), (('CLLO', '1100'),), (('COMP', '1100'),), (('DRUM', '1100'),), (('ENGL', '1100'),), (('EUPH', '1100'),), (('FDDL', '1100'),), (('FLUT', '1100'),), (('GTR', '1100'),), (('HARP', '1100'),), (('HART', '1100'),), (('HORN', '1100'),), (('HRPS', '1100'),), (('JAZZ', '1100'),), (('MATH', '1100'),), (('MGRL', '1100'),), (('MNDL', '1100'),), (('MUSL', '1100'),), (('NS', '1100'),), (('OBOE', '1100'),), (('ORGN', '1100'),), (('PERC', '1100'),), (('PHIL', '1100'),), (('PIAN', '1100'),), (('PSCI', '1100'),), (('RLST', '1100'),), (('SAX', '1100'),), (('SPAN', '1100'),), (('STPN', '1100'),)))
# Course(program='CS', designation='open2') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BASS', '1000'),), (('BSSN', '1000'),), (('CLAR', '1000'),), (('CLLO', '1000'),), (('COMP', '1000'),), (('FLUT', '1000'),), (('GTR', '1000'),), (('HARP', '1000'),), (('HORN', '1000'),), (('MUSO', '1000'),), (('OBOE', '1000'),), (('PERC', '1000'),), (('PIAN', '1000'),), (('SAX', '1000'),), (('AADS', '1001'),), (('ANTH', '1001'),), (('ARTS', '1001'),), (('ASTR', '1001'),), (('BSCI', '1001'),), (('CMST', '1001'),), (('EDUC', '1001'),), (('EES', '1001'),), (('ES', '1001'),), (('EUS', '1001'),), (('ITA', '1001'),), (('MGRL', '1001'),), (('MHS', '1001'),), (('MUSO', '1001'),), (('NSC', '1001'),), (('PSCI', '1001'),), (('PSY', '1001'),), (('RLST', '1001'),), (('SOC', '1001'),), (('SPAN', '1001'),), (('SPED', '1001'),), (('AMER', '1002'),), (('CMST', '1002'),), (('PHIL', '1002'),), (('AMER', '1002W'),), (('CMA', '1002W'),), (('JS', '1002W'),), (('PHIL', '1002W'),), (('PHIL', '1003'),), (('MATH', '1005'),), (('PHIL', '1005'),), (('PHIL', '1008'),), (('PHIL', '1008W'),), (('AADS', '1010'),), (('ASTR', '1010'),), (('CHEM', '1010'),), (('CLAS', '1010'),), (('ECON', '1010'),), (('GTR', '1010'),), (('MATH', '1010'),), (('MUED', '1010'),), (('MUSE', '1010'),), (('PERC', '1010'),), (('PHYS', '1010'),), (('PIAN', '1010'),), (('RLST', '1010'),), (('SOC', '1010'),), (('STPN', '1010'),), (('SOC', '1010W'),), (('CHIN', '1011'),), (('JAPN', '1011'),), (('MATH', '1011'),), (('CHIN', '1012'),), (('JAPN', '1012'),), (('AADS', '1016'),), (('CHEM', '1020'),), (('ECON', '1020'),), (('GTR', '1020'),), (('MUED', '1020'),), (('MUSE', '1020'),), (('PIAN', '1020'),), (('SOC', '1020'),), (('ASTR', '1020L'),), (('CHEM', '1020L'),), (('SOC', '1020W'),), (('EES', '1030'),), (('GTR', '1030'),), (('MUED', '1030'),), (('MUSE', '1030'),), (('EES', '1030L'),), (('MUED', '1040'),), (('SOC', '1041'),), (('SOC', '1041W'),), (('MUED', '1050'),), (('HIST', '1060'),), (('MUED', '1060'),), (('HIST', '1070'),), (('MUED', '1070'),), (('EES', '1080'),), (('HIST', '1080'),), (('HIST', '1090'),), (('BASS', '1100'),), (('BNJO', '1100'),), (('BRQ', '1100'),), (('BSCI', '1100'),), (('BSSN', '1100'),), (('CLAR', '1100'),), (('CLLO', '1100'),), (('COMP', '1100'),), (('DRUM', '1100'),), (('ENGL', '1100'),), (('EUPH', '1100'),), (('FDDL', '1100'),), (('FLUT', '1100'),), (('GTR', '1100'),), (('HARP', '1100'),), (('HART', '1100'),), (('HORN', '1100'),), (('HRPS', '1100'),), (('JAZZ', '1100'),), (('MATH', '1100'),), (('MGRL', '1100'),), (('MNDL', '1100'),), (('MUSL', '1100'),), (('NS', '1100'),), (('OBOE', '1100'),), (('ORGN', '1100'),), (('PERC', '1100'),), (('PHIL', '1100'),), (('PIAN', '1100'),), (('PSCI', '1100'),), (('RLST', '1100'),), (('SAX', '1100'),), (('SPAN', '1100'),), (('STPN', '1100'),)))
# Course(program='CS', designation='open3') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BASS', '1000'),), (('BSSN', '1000'),), (('CLAR', '1000'),), (('CLLO', '1000'),), (('COMP', '1000'),), (('FLUT', '1000'),), (('GTR', '1000'),), (('HARP', '1000'),), (('HORN', '1000'),), (('MUSO', '1000'),), (('OBOE', '1000'),), (('PERC', '1000'),), (('PIAN', '1000'),), (('SAX', '1000'),), (('AADS', '1001'),), (('ANTH', '1001'),), (('ARTS', '1001'),), (('ASTR', '1001'),), (('BSCI', '1001'),), (('CMST', '1001'),), (('EDUC', '1001'),), (('EES', '1001'),), (('ES', '1001'),), (('EUS', '1001'),), (('ITA', '1001'),), (('MGRL', '1001'),), (('MHS', '1001'),), (('MUSO', '1001'),), (('NSC', '1001'),), (('PSCI', '1001'),), (('PSY', '1001'),), (('RLST', '1001'),), (('SOC', '1001'),), (('SPAN', '1001'),), (('SPED', '1001'),), (('AMER', '1002'),), (('CMST', '1002'),), (('PHIL', '1002'),), (('AMER', '1002W'),), (('CMA', '1002W'),), (('JS', '1002W'),), (('PHIL', '1002W'),), (('PHIL', '1003'),), (('MATH', '1005'),), (('PHIL', '1005'),), (('PHIL', '1008'),), (('PHIL', '1008W'),), (('AADS', '1010'),), (('ASTR', '1010'),), (('CHEM', '1010'),), (('CLAS', '1010'),), (('ECON', '1010'),), (('GTR', '1010'),), (('MATH', '1010'),), (('MUED', '1010'),), (('MUSE', '1010'),), (('PERC', '1010'),), (('PHYS', '1010'),), (('PIAN', '1010'),), (('RLST', '1010'),), (('SOC', '1010'),), (('STPN', '1010'),), (('SOC', '1010W'),), (('CHIN', '1011'),), (('JAPN', '1011'),), (('MATH', '1011'),), (('CHIN', '1012'),), (('JAPN', '1012'),), (('AADS', '1016'),), (('CHEM', '1020'),), (('ECON', '1020'),), (('GTR', '1020'),), (('MUED', '1020'),), (('MUSE', '1020'),), (('PIAN', '1020'),), (('SOC', '1020'),), (('ASTR', '1020L'),), (('CHEM', '1020L'),), (('SOC', '1020W'),), (('EES', '1030'),), (('GTR', '1030'),), (('MUED', '1030'),), (('MUSE', '1030'),), (('EES', '1030L'),), (('MUED', '1040'),), (('SOC', '1041'),), (('SOC', '1041W'),), (('MUED', '1050'),), (('HIST', '1060'),), (('MUED', '1060'),), (('HIST', '1070'),), (('MUED', '1070'),), (('EES', '1080'),), (('HIST', '1080'),), (('HIST', '1090'),), (('BASS', '1100'),), (('BNJO', '1100'),), (('BRQ', '1100'),), (('BSCI', '1100'),), (('BSSN', '1100'),), (('CLAR', '1100'),), (('CLLO', '1100'),), (('COMP', '1100'),), (('DRUM', '1100'),), (('ENGL', '1100'),), (('EUPH', '1100'),), (('FDDL', '1100'),), (('FLUT', '1100'),), (('GTR', '1100'),), (('HARP', '1100'),), (('HART', '1100'),), (('HORN', '1100'),), (('HRPS', '1100'),), (('JAZZ', '1100'),), (('MATH', '1100'),), (('MGRL', '1100'),), (('MNDL', '1100'),), (('MUSL', '1100'),), (('NS', '1100'),), (('OBOE', '1100'),), (('ORGN', '1100'),), (('PERC', '1100'),), (('PHIL', '1100'),), (('PIAN', '1100'),), (('PSCI', '1100'),), (('RLST', '1100'),), (('SAX', '1100'),), (('SPAN', '1100'),), (('STPN', '1100'),)))
# Course(program='CS', designation='open4') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BASS', '1000'),), (('BSSN', '1000'),), (('CLAR', '1000'),), (('CLLO', '1000'),), (('COMP', '1000'),), (('FLUT', '1000'),), (('GTR', '1000'),), (('HARP', '1000'),), (('HORN', '1000'),), (('MUSO', '1000'),), (('OBOE', '1000'),), (('PERC', '1000'),), (('PIAN', '1000'),), (('SAX', '1000'),), (('AADS', '1001'),), (('ANTH', '1001'),), (('ARTS', '1001'),), (('ASTR', '1001'),), (('BSCI', '1001'),), (('CMST', '1001'),), (('EDUC', '1001'),), (('EES', '1001'),), (('ES', '1001'),), (('EUS', '1001'),), (('ITA', '1001'),), (('MGRL', '1001'),), (('MHS', '1001'),), (('MUSO', '1001'),), (('NSC', '1001'),), (('PSCI', '1001'),), (('PSY', '1001'),), (('RLST', '1001'),), (('SOC', '1001'),), (('SPAN', '1001'),), (('SPED', '1001'),), (('AMER', '1002'),), (('CMST', '1002'),), (('PHIL', '1002'),), (('AMER', '1002W'),), (('CMA', '1002W'),), (('JS', '1002W'),), (('PHIL', '1002W'),), (('PHIL', '1003'),), (('MATH', '1005'),), (('PHIL', '1005'),), (('PHIL', '1008'),), (('PHIL', '1008W'),), (('AADS', '1010'),), (('ASTR', '1010'),), (('CHEM', '1010'),), (('CLAS', '1010'),), (('ECON', '1010'),), (('GTR', '1010'),), (('MATH', '1010'),), (('MUED', '1010'),), (('MUSE', '1010'),), (('PERC', '1010'),), (('PHYS', '1010'),), (('PIAN', '1010'),), (('RLST', '1010'),), (('SOC', '1010'),), (('STPN', '1010'),), (('SOC', '1010W'),), (('CHIN', '1011'),), (('JAPN', '1011'),), (('MATH', '1011'),), (('CHIN', '1012'),), (('JAPN', '1012'),), (('AADS', '1016'),), (('CHEM', '1020'),), (('ECON', '1020'),), (('GTR', '1020'),), (('MUED', '1020'),), (('MUSE', '1020'),), (('PIAN', '1020'),), (('SOC', '1020'),), (('ASTR', '1020L'),), (('CHEM', '1020L'),), (('SOC', '1020W'),), (('EES', '1030'),), (('GTR', '1030'),), (('MUED', '1030'),), (('MUSE', '1030'),), (('EES', '1030L'),), (('MUED', '1040'),), (('SOC', '1041'),), (('SOC', '1041W'),), (('MUED', '1050'),), (('HIST', '1060'),), (('MUED', '1060'),), (('HIST', '1070'),), (('MUED', '1070'),), (('EES', '1080'),), (('HIST', '1080'),), (('HIST', '1090'),), (('BASS', '1100'),), (('BNJO', '1100'),), (('BRQ', '1100'),), (('BSCI', '1100'),), (('BSSN', '1100'),), (('CLAR', '1100'),), (('CLLO', '1100'),), (('COMP', '1100'),), (('DRUM', '1100'),), (('ENGL', '1100'),), (('EUPH', '1100'),), (('FDDL', '1100'),), (('FLUT', '1100'),), (('GTR', '1100'),), (('HARP', '1100'),), (('HART', '1100'),), (('HORN', '1100'),), (('HRPS', '1100'),), (('JAZZ', '1100'),), (('MATH', '1100'),), (('MGRL', '1100'),), (('MNDL', '1100'),), (('MUSL', '1100'),), (('NS', '1100'),), (('OBOE', '1100'),), (('ORGN', '1100'),), (('PERC', '1100'),), (('PHIL', '1100'),), (('PIAN', '1100'),), (('PSCI', '1100'),), (('RLST', '1100'),), (('SAX', '1100'),), (('SPAN', '1100'),), (('STPN', '1100'),)))
# Course(program='CS', designation='open5') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BASS', '1000'),), (('BSSN', '1000'),), (('CLAR', '1000'),), (('CLLO', '1000'),), (('COMP', '1000'),), (('FLUT', '1000'),), (('GTR', '1000'),), (('HARP', '1000'),), (('HORN', '1000'),), (('MUSO', '1000'),), (('OBOE', '1000'),), (('PERC', '1000'),), (('PIAN', '1000'),), (('SAX', '1000'),), (('AADS', '1001'),), (('ANTH', '1001'),), (('ARTS', '1001'),), (('ASTR', '1001'),), (('BSCI', '1001'),), (('CMST', '1001'),), (('EDUC', '1001'),), (('EES', '1001'),), (('ES', '1001'),), (('EUS', '1001'),), (('ITA', '1001'),), (('MGRL', '1001'),), (('MHS', '1001'),), (('MUSO', '1001'),), (('NSC', '1001'),), (('PSCI', '1001'),), (('PSY', '1001'),), (('RLST', '1001'),), (('SOC', '1001'),), (('SPAN', '1001'),), (('SPED', '1001'),), (('AMER', '1002'),), (('CMST', '1002'),), (('PHIL', '1002'),), (('AMER', '1002W'),), (('CMA', '1002W'),), (('JS', '1002W'),), (('PHIL', '1002W'),), (('PHIL', '1003'),), (('MATH', '1005'),), (('PHIL', '1005'),), (('PHIL', '1008'),), (('PHIL', '1008W'),), (('AADS', '1010'),), (('ASTR', '1010'),), (('CHEM', '1010'),), (('CLAS', '1010'),), (('ECON', '1010'),), (('GTR', '1010'),), (('MATH', '1010'),), (('MUED', '1010'),), (('MUSE', '1010'),), (('PERC', '1010'),), (('PHYS', '1010'),), (('PIAN', '1010'),), (('RLST', '1010'),), (('SOC', '1010'),), (('STPN', '1010'),), (('SOC', '1010W'),), (('CHIN', '1011'),), (('JAPN', '1011'),), (('MATH', '1011'),), (('CHIN', '1012'),), (('JAPN', '1012'),), (('AADS', '1016'),), (('CHEM', '1020'),), (('ECON', '1020'),), (('GTR', '1020'),), (('MUED', '1020'),), (('MUSE', '1020'),), (('PIAN', '1020'),), (('SOC', '1020'),), (('ASTR', '1020L'),), (('CHEM', '1020L'),), (('SOC', '1020W'),), (('EES', '1030'),), (('GTR', '1030'),), (('MUED', '1030'),), (('MUSE', '1030'),), (('EES', '1030L'),), (('MUED', '1040'),), (('SOC', '1041'),), (('SOC', '1041W'),), (('MUED', '1050'),), (('HIST', '1060'),), (('MUED', '1060'),), (('HIST', '1070'),), (('MUED', '1070'),), (('EES', '1080'),), (('HIST', '1080'),), (('HIST', '1090'),), (('BASS', '1100'),), (('BNJO', '1100'),), (('BRQ', '1100'),), (('BSCI', '1100'),), (('BSSN', '1100'),), (('CLAR', '1100'),), (('CLLO', '1100'),), (('COMP', '1100'),), (('DRUM', '1100'),), (('ENGL', '1100'),), (('EUPH', '1100'),), (('FDDL', '1100'),), (('FLUT', '1100'),), (('GTR', '1100'),), (('HARP', '1100'),), (('HART', '1100'),), (('HORN', '1100'),), (('HRPS', '1100'),), (('JAZZ', '1100'),), (('MATH', '1100'),), (('MGRL', '1100'),), (('MNDL', '1100'),), (('MUSL', '1100'),), (('NS', '1100'),), (('OBOE', '1100'),), (('ORGN', '1100'),), (('PERC', '1100'),), (('PHIL', '1100'),), (('PIAN', '1100'),), (('PSCI', '1100'),), (('RLST', '1100'),), (('SAX', '1100'),), (('SPAN', '1100'),), (('STPN', '1100'),)))
# Course(program='CS', designation='open6') CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BASS', '1000'),), (('BSSN', '1000'),), (('CLAR', '1000'),), (('CLLO', '1000'),), (('COMP', '1000'),), (('FLUT', '1000'),), (('GTR', '1000'),), (('HARP', '1000'),), (('HORN', '1000'),), (('MUSO', '1000'),), (('OBOE', '1000'),), (('PERC', '1000'),), (('PIAN', '1000'),), (('SAX', '1000'),), (('AADS', '1001'),), (('ANTH', '1001'),), (('ARTS', '1001'),), (('ASTR', '1001'),), (('BSCI', '1001'),), (('CMST', '1001'),), (('EDUC', '1001'),), (('EES', '1001'),), (('ES', '1001'),), (('EUS', '1001'),), (('ITA', '1001'),), (('MGRL', '1001'),), (('MHS', '1001'),), (('MUSO', '1001'),), (('NSC', '1001'),), (('PSCI', '1001'),), (('PSY', '1001'),), (('RLST', '1001'),), (('SOC', '1001'),), (('SPAN', '1001'),), (('SPED', '1001'),), (('AMER', '1002'),), (('CMST', '1002'),), (('PHIL', '1002'),), (('AMER', '1002W'),), (('CMA', '1002W'),), (('JS', '1002W'),), (('PHIL', '1002W'),), (('PHIL', '1003'),), (('MATH', '1005'),), (('PHIL', '1005'),), (('PHIL', '1008'),), (('PHIL', '1008W'),), (('AADS', '1010'),), (('ASTR', '1010'),), (('CHEM', '1010'),), (('CLAS', '1010'),), (('ECON', '1010'),), (('GTR', '1010'),), (('MATH', '1010'),), (('MUED', '1010'),), (('MUSE', '1010'),), (('PERC', '1010'),), (('PHYS', '1010'),), (('PIAN', '1010'),), (('RLST', '1010'),), (('SOC', '1010'),), (('STPN', '1010'),), (('SOC', '1010W'),), (('CHIN', '1011'),), (('JAPN', '1011'),), (('MATH', '1011'),), (('CHIN', '1012'),), (('JAPN', '1012'),), (('AADS', '1016'),), (('CHEM', '1020'),), (('ECON', '1020'),), (('GTR', '1020'),), (('MUED', '1020'),), (('MUSE', '1020'),), (('PIAN', '1020'),), (('SOC', '1020'),), (('ASTR', '1020L'),), (('CHEM', '1020L'),), (('SOC', '1020W'),), (('EES', '1030'),), (('GTR', '1030'),), (('MUED', '1030'),), (('MUSE', '1030'),), (('EES', '1030L'),), (('MUED', '1040'),), (('SOC', '1041'),), (('SOC', '1041W'),), (('MUED', '1050'),), (('HIST', '1060'),), (('MUED', '1060'),), (('HIST', '1070'),), (('MUED', '1070'),), (('EES', '1080'),), (('HIST', '1080'),), (('HIST', '1090'),), (('BASS', '1100'),), (('BNJO', '1100'),), (('BRQ', '1100'),), (('BSCI', '1100'),), (('BSSN', '1100'),), (('CLAR', '1100'),), (('CLLO', '1100'),), (('COMP', '1100'),), (('DRUM', '1100'),), (('ENGL', '1100'),), (('EUPH', '1100'),), (('FDDL', '1100'),), (('FLUT', '1100'),), (('GTR', '1100'),), (('HARP', '1100'),), (('HART', '1100'),), (('HORN', '1100'),), (('HRPS', '1100'),), (('JAZZ', '1100'),), (('MATH', '1100'),), (('MGRL', '1100'),), (('MNDL', '1100'),), (('MUSL', '1100'),), (('NS', '1100'),), (('OBOE', '1100'),), (('ORGN', '1100'),), (('PERC', '1100'),), (('PHIL', '1100'),), (('PIAN', '1100'),), (('PSCI', '1100'),), (('RLST', '1100'),), (('SAX', '1100'),), (('SPAN', '1100'),), (('STPN', '1100'),)))
# Course(program='CS', designation='4959') CourseInfo(credits='1', terms=('Fall',), prereqs=((('CS', '3281'),),))
# Course(program='CS', designation='1101') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=())
# Course(program='CS', designation='1103') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=())
# Course(program='CS', designation='1151') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='CS', designation='2201') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '1101'),),))
# Course(program='CS', designation='2212') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='CS', designation='2231') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '2201'),),))
# Course(program='CS', designation='3250') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '2201'), ('CS', '2212')),))
# Course(program='CS', designation='3251') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '2201'),),))
# Course(program='CS', designation='3259') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CS', '2201'), ('MATH', '2410')), (('CS', '2201'), ('MATH', '2400')), (('CS', '2201'), ('MATH', '2600')), (('CS', '2201'), ('MATH', '2501'))))
# Course(program='CS', designation='3270') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '2231'),),))
# Course(program='CS', designation='3281') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '2231'), ('CS', '3251')),))
# Course(program='CS', designation='3282') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CS', '3281'),),))
# Course(program='CS', designation='4260') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '3250'),),))
# Course(program='CS', designation='4278') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '3251'),),))
# Course(program='CS', designation='4285') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '4283'),),))
# Course(program='CS', designation='4287') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CS', '3281'),),))
# Course(program='CS', designation='2204') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '1101'),), (('CS', '1103'),)))
# Course(program='CS', designation='3252') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CS', '2212'),),))
# Course(program='CS', designation='3265') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CS', '2201'),),))
# Course(program='CS', designation='3274') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CS', '2201'),),))
# Course(program='CS', designation='4269') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '4260'),),))
# Course(program='CS', designation='4279') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CS', '4278'),),))
# Course(program='CS', designation='4283') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CS', '3281'),), (('EECE', '4376'),)))
# Course(program='CS', designation='4288') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CS', '3251'),),))
# Course(program='CS', designation='3258') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CS', '3251'), ('MATH', '2410')), (('CS', '3251'), ('MATH', '2400')), (('CS', '3251'), ('MATH', '2600')), (('CS', '3251'), ('MATH', '2501'))))
# Course(program='CS', designation='3276') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CS', '2231'),),))
# Course(program='CS', designation='4266') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CS', '3251'),),))

# %%
# Prints the entire dictionary.
course_dictionary.print_dict(test)
print(test[('CS', 'open3')])
# Out:
# Course(program='AADS', designation='3850') CourseInfo(credits=3, terms=('Spring',), prereqs=())
# Course(program='AADS', designation='1001') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='AADS', designation='1010') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='AADS', designation='1506') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='1706') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='AADS', designation='2166') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='2168') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='2178') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='2214') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='AADS', designation='2294') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='3214') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='4979') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='AADS', designation='1016') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='AADS', designation='2148') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='AADS', designation='2356') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='AADS', designation='3104W') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='AADS', designation='3278') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='AADS', designation='4270') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='AADS', designation='2104') CourseInfo(credits='3', terms=('Summer', 'Fall'), prereqs=())
# Course(program='AADS', designation='2106') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='2654') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='3204W') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='3206') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='3248') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='4198') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='4256') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AADS', designation='1204') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='AADS', designation='2204') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='AADS', designation='4228W') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AMER', designation='3851') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='AMER', designation='3852') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='AMER', designation='4100') CourseInfo(credits=3, terms=('Spring',), prereqs=())
# Course(program='AMER', designation='1111') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='AMER', designation='3880') CourseInfo(credits=3, terms=('Spring',), prereqs=())
# Course(program='AMER', designation='3881') CourseInfo(credits=3, terms=('Spring',), prereqs=())
# Course(program='AMER', designation='1002') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='AMER', designation='1002W') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=())
# Course(program='AMER', designation='1200') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='AMER', designation='3890') CourseInfo(credits='3', terms=('Summer', 'Fall'), prereqs=())
# Course(program='AMER', designation='4000') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='AMER', designation='3830') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='AMER', designation='4960') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='AMER', designation='3200') CourseInfo(credits='3', terms=('Summer', 'Fall'), prereqs=())
# Course(program='AMER', designation='4998') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='1111') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='4999') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=((('ANTH', '4998'),),))
# Course(program='ANTH', designation='3850') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='4998') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='1001') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='1101') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='1201') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='1201W') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='2113W') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='2211') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='2220W') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='2231') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='3122') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='3141') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='3144') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='3161') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='3200') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='3262') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='3372') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='3900') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='4154') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='1301') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='1601') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='2106') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='2250') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3133') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3138') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3150W') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3162') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3241') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='3243W') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3250') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3261') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3343') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3622W') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3890') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='2227') CourseInfo(credits='3', terms=('Summer', 'Fall'), prereqs=())
# Course(program='ANTH', designation='2105') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='2109') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='2214') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='3132') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='3140') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='3202') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='2222') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='2242W') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3120') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ANTH', designation='3134') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='3240') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='4373') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ANTH', designation='2375') CourseInfo(credits='3', terms=('Summer',), prereqs=())
# Course(program='ANTH', designation='1130W') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='2150') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='2223') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='4153') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ANTH', designation='4345') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BSCI', '1100'),), (('BSCI', '1105'),), (('BSCI', '1510'),)))
# Course(program='ANTH', designation='3866') CourseInfo(credits='4', terms=('Fall',), prereqs=())
# Course(program='ARA', designation='3101') CourseInfo(credits='3', terms=('Fall',), prereqs=((('ARA', '2202'),),))
# Course(program='ARA', designation='3301') CourseInfo(credits='3', terms=('Fall',), prereqs=((('ARA', '2201'),),))
# Course(program='ARA', designation='3102') CourseInfo(credits='3', terms=('Spring',), prereqs=((('ARA', '3101'),),))
# Course(program='ARA', designation='2201') CourseInfo(credits='4', terms=('Spring', 'Fall'), prereqs=((('ARA', '1102'),),))
# Course(program='ARA', designation='2202') CourseInfo(credits='4', terms=('Spring',), prereqs=((('ARA', '2201'),),))
# Course(program='ARA', designation='1101') CourseInfo(credits='5', terms=('Summer', 'Fall'), prereqs=())
# Course(program='ARA', designation='1102') CourseInfo(credits='5', terms=('Spring', 'Fall'), prereqs=((('ARA', '1101'),),))
# Course(program='ARTS', designation='1111') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='ARTS', designation='3851') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='ARTS', designation='1001') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='ARTS', designation='1102') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=())
# Course(program='ARTS', designation='1200') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ARTS', designation='1300') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('ARTS', '1102'),),))
# Course(program='ARTS', designation='1400') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=())
# Course(program='ARTS', designation='1401') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ARTS', designation='1500') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ARTS', designation='1700') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ARTS', designation='2101') CourseInfo(credits='3', terms=('Fall',), prereqs=((('ARTS', '1102'),),))
# Course(program='ARTS', designation='2102') CourseInfo(credits='3', terms=('Fall',), prereqs=((('ARTS', '1102'),),))
# Course(program='ARTS', designation='2200') CourseInfo(credits='3', terms=('Fall',), prereqs=((('ARTS', '1200'),), (('ARTS', '1201'),), (('ARTS', '1202'),)))
# Course(program='ARTS', designation='2401') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('ARTS', '1400'),), (('ARTS', '1401'),)))
# Course(program='ARTS', designation='2700') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('ARTS', '1700'),),))
# Course(program='ARTS', designation='3102') CourseInfo(credits='3', terms=('Fall',), prereqs=((('ARTS', '2102'),),))
# Course(program='ARTS', designation='3970') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ARTS', designation='4998') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ARTS', designation='1101') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ARTS', designation='1201') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ARTS', designation='1202') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ARTS', designation='1501') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ARTS', designation='1502') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ARTS', designation='1503') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ARTS', designation='1601') CourseInfo(credits='3', terms=('Spring',), prereqs=((('ARTS', '1102'),),))
# Course(program='ARTS', designation='1701') CourseInfo(credits='3', terms=('Sprint', 'Fall'), prereqs=())
# Course(program='ARTS', designation='1702') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ARTS', designation='1800') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ARTS', designation='2100') CourseInfo(credits='3', terms=('Summer', 'Spring'), prereqs=((('ARTS', '1102'),),))
# Course(program='ARTS', designation='2202') CourseInfo(credits='3', terms=('Spring',), prereqs=((('ARTS', '1202'),),))
# Course(program='ARTS', designation='2300') CourseInfo(credits='3', terms=('Spring',), prereqs=((('ARTS', '1300'),),))
# Course(program='ARTS', designation='2400') CourseInfo(credits='3', terms=('Spring',), prereqs=((('ARTS', '1400'),),))
# Course(program='ARTS', designation='2600') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('ARTS', '1600'),), (('ARTS', '1601'),)))
# Course(program='ARTS', designation='2702') CourseInfo(credits='3', terms=('Spring',), prereqs=((('ARTS', '1700'),), (('ARTS', '1701'),), (('ARTS', '1702'),)))
# Course(program='ARTS', designation='3300') CourseInfo(credits='3', terms=('Spring',), prereqs=((('ARTS', '2300'),),))
# Course(program='ARTS', designation='3971') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ARTS', designation='4999') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ARTS', designation='1600') CourseInfo(credits='3', terms=('Fall',), prereqs=((('ARTS', '1102'),),))
# Course(program='ARTS', designation='2500') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('ARTS', '1500'),), (('ARTS', '1501'),), (('ARTS', '1502'),)))
# Course(program='ARTS', designation='2502') CourseInfo(credits='3', terms=('Spring',), prereqs=((('ARTS', '1502'),),))
# Course(program='ARTS', designation='3600') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('ARTS', '2600'),),))
# Course(program='ASIA', designation='1111') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='ASIA', designation='3891') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='ASIA', designation='3851') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='ASIA', designation='4998') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='ASIA', designation='4999') CourseInfo(credits=3, terms=('Spring',), prereqs=((('ASIA', '4998'),),))
# Course(program='ASIA', designation='3151') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ASIA', designation='2100W') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ASIA', designation='2511') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ASIA', designation='2560') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ASIA', designation='2605') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ASIA', designation='2606') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ASIA', designation='3633') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ASIA', designation='1680') CourseInfo(credits='3', terms=('Summer',), prereqs=())
# Course(program='ASIA', designation='2607') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ASIA', designation='2608') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ASIA', designation='2630') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='ASIA', designation='2512') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ASIA', designation='2609W') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ASTR', designation='3840') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='ASTR', designation='3860') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='ASTR', designation='4998') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='ASTR', designation='1111') CourseInfo(credits=3, terms=('Spring',), prereqs=())
# Course(program='ASTR', designation='3890') CourseInfo(credits=3, terms=('Summer',), prereqs=())
# Course(program='ASTR', designation='1010L') CourseInfo(credits='1', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ASTR', designation='1120L') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='ASTR', designation='2600') CourseInfo(credits='1', terms=('Spring', 'Fall'), prereqs=((('ASTR', '1010'),),))
# Course(program='ASTR', designation='1001') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='ASTR', designation='1020L') CourseInfo(credits='1', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ASTR', designation='1010') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='ASTR', designation='3000') CourseInfo(credits='3', terms=('Fall',), prereqs=((('PHYS', '1501'), ('MATH', '1200')), (('PHYS', '1601'), ('MATH', '1200')), (('PHYS', '1901'), ('MATH', '1200')), (('PHYS', '1501'), ('MATH', '1300')), (('PHYS', '1601'), ('MATH', '1300')), (('PHYS', '1901'), ('MATH', '1300'))))
# Course(program='ASTR', designation='3700') CourseInfo(credits='3', terms=('Fall',), prereqs=((('MATH', '2420'), ('PHYS', '2250')), (('MATH', '2420'), ('PHYS', '2250W'))))
# Course(program='ASTR', designation='2110') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ASTR', designation='2130') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='ASTR', designation='3800') CourseInfo(credits='3', terms=('Spring',), prereqs=((('PHYS', '1501'), ('PHYS', '1502'), ('MATH', '2400'), ('CS', '1101')), (('PHYS', '1501'), ('PHYS', '1502'), ('MATH', '2400'), ('CS', '1103')), (('PHYS', '1501'), ('PHYS', '1502'), ('MATH', '2420'), ('CS', '1101')), (('PHYS', '1501'), ('PHYS', '1502'), ('MATH', '2420'), ('CS', '1103')), (('PHYS', '1501'), ('PHYS', '1502'), ('MATH', '2610'), ('CS', '1101')), (('PHYS', '1501'), ('PHYS', '1502'), ('MATH', '2610'), ('CS', '1103')), (('PHYS', '1501'), ('PHYS', '1602'), ('MATH', '2400'), ('CS', '1101')), (('PHYS', '1501'), ('PHYS', '1602'), ('MATH', '2400'), ('CS', '1103')), (('PHYS', '1501'), ('PHYS', '1602'), ('MATH', '2420'), ('CS', '1101')), (('PHYS', '1501'), ('PHYS', '1602'), ('MATH', '2420'), ('CS', '1103')), (('PHYS', '1501'), ('PHYS', '1602'), ('MATH', '2610'), ('CS', '1101')), (('PHYS', '1501'), ('PHYS', '1602'), ('MATH', '2610'), ('CS', '1103')), (('PHYS', '1501'), ('PHYS', '1902'), ('MATH', '2400'), ('CS', '1101')), (('PHYS', '1501'), ('PHYS', '1902'), ('MATH', '2400'), ('CS', '1103')), (('PHYS', '1501'), ('PHYS', '1902'), ('MATH', '2420'), ('CS', '1101')), (('PHYS', '1501'), ('PHYS', '1902'), ('MATH', '2420'), ('CS', '1103')), (('PHYS', '1501'), ('PHYS', '1902'), ('MATH', '2610'), ('CS', '1101')), (('PHYS', '1501'), ('PHYS', '1902'), ('MATH', '2610'), ('CS', '1103')), (('PHYS', '1601'), ('PHYS', '1502'), ('MATH', '2400'), ('CS', '1101')), (('PHYS', '1601'), ('PHYS', '1502'), ('MATH', '2400'), ('CS', '1103')), (('PHYS', '1601'), ('PHYS', '1502'), ('MATH', '2420'), ('CS', '1101')), (('PHYS', '1601'), ('PHYS', '1502'), ('MATH', '2420'), ('CS', '1103')), (('PHYS', '1601'), ('PHYS', '1502'), ('MATH', '2610'), ('CS', '1101')), (('PHYS', '1601'), ('PHYS', '1502'), ('MATH', '2610'), ('CS', '1103')), (('PHYS', '1601'), ('PHYS', '1602'), ('MATH', '2400'), ('CS', '1101')), (('PHYS', '1601'), ('PHYS', '1602'), ('MATH', '2400'), ('CS', '1103')), (('PHYS', '1601'), ('PHYS', '1602'), ('MATH', '2420'), ('CS', '1101')), (('PHYS', '1601'), ('PHYS', '1602'), ('MATH', '2420'), ('CS', '1103')), (('PHYS', '1601'), ('PHYS', '1602'), ('MATH', '2610'), ('CS', '1101')), (('PHYS', '1601'), ('PHYS', '1602'), ('MATH', '2610'), ('CS', '1103')), (('PHYS', '1601'), ('PHYS', '1902'), ('MATH', '2400'), ('CS', '1101')), (('PHYS', '1601'), ('PHYS', '1902'), ('MATH', '2400'), ('CS', '1103')), (('PHYS', '1601'), ('PHYS', '1902'), ('MATH', '2420'), ('CS', '1101')), (('PHYS', '1601'), ('PHYS', '1902'), ('MATH', '2420'), ('CS', '1103')), (('PHYS', '1601'), ('PHYS', '1902'), ('MATH', '2610'), ('CS', '1101')), (('PHYS', '1601'), ('PHYS', '1902'), ('MATH', '2610'), ('CS', '1103')), (('PHYS', '1901'), ('PHYS', '1502'), ('MATH', '2400'), ('CS', '1101')), (('PHYS', '1901'), ('PHYS', '1502'), ('MATH', '2400'), ('CS', '1103')), (('PHYS', '1901'), ('PHYS', '1502'), ('MATH', '2420'), ('CS', '1101')), (('PHYS', '1901'), ('PHYS', '1502'), ('MATH', '2420'), ('CS', '1103')), (('PHYS', '1901'), ('PHYS', '1502'), ('MATH', '2610'), ('CS', '1101')), (('PHYS', '1901'), ('PHYS', '1502'), ('MATH', '2610'), ('CS', '1103')), (('PHYS', '1901'), ('PHYS', '1602'), ('MATH', '2400'), ('CS', '1101')), (('PHYS', '1901'), ('PHYS', '1602'), ('MATH', '2400'), ('CS', '1103')), (('PHYS', '1901'), ('PHYS', '1602'), ('MATH', '2420'), ('CS', '1101')), (('PHYS', '1901'), ('PHYS', '1602'), ('MATH', '2420'), ('CS', '1103')), (('PHYS', '1901'), ('PHYS', '1602'), ('MATH', '2610'), ('CS', '1101')), (('PHYS', '1901'), ('PHYS', '1602'), ('MATH', '2610'), ('CS', '1103')), (('PHYS', '1901'), ('PHYS', '1902'), ('MATH', '2400'), ('CS', '1101')), (('PHYS', '1901'), ('PHYS', '1902'), ('MATH', '2400'), ('CS', '1103')), (('PHYS', '1901'), ('PHYS', '1902'), ('MATH', '2420'), ('CS', '1101')), (('PHYS', '1901'), ('PHYS', '1902'), ('MATH', '2420'), ('CS', '1103')), (('PHYS', '1901'), ('PHYS', '1902'), ('MATH', '2610'), ('CS', '1101')), (('PHYS', '1901'), ('PHYS', '1902'), ('MATH', '2610'), ('CS', '1103'))))
# Course(program='ASTR', designation='3600') CourseInfo(credits='3', terms=('Fall',), prereqs=((('PHYS', '3200'), ('PHYS', '2250'), ('MATH', '2400')), (('PHYS', '3200'), ('PHYS', '2250'), ('MATH', '2420')), (('PHYS', '3200'), ('PHYS', '2250'), ('MATH', '2610')), (('PHYS', '3200'), ('PHYS', '2250W'), ('MATH', '2400')), (('PHYS', '3200'), ('PHYS', '2250W'), ('MATH', '2420')), (('PHYS', '3200'), ('PHYS', '2250W'), ('MATH', '2610')), (('PHYS', '3207'), ('PHYS', '2250'), ('MATH', '2400')), (('PHYS', '3207'), ('PHYS', '2250'), ('MATH', '2420')), (('PHYS', '3207'), ('PHYS', '2250'), ('MATH', '2610')), (('PHYS', '3207'), ('PHYS', '2250W'), ('MATH', '2400')), (('PHYS', '3207'), ('PHYS', '2250W'), ('MATH', '2420')), (('PHYS', '3207'), ('PHYS', '2250W'), ('MATH', '2610'))))
# Course(program='ASTR', designation='1210') CourseInfo(credits='4', terms=('Summer',), prereqs=())
# Course(program='BASS', designation='1100') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='BASS', designation='1000') CourseInfo(credits='1', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BASS', designation='2100') CourseInfo(credits='2', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BASS', designation='4100') CourseInfo(credits='2', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BASS', designation='2200') CourseInfo(credits='4', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BASS', designation='4200') CourseInfo(credits='4', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BCB', designation='3201') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=((('BSCI', '1510'), ('CHEM', '1020')), (('BSCI', '1510'), ('CHEM', '1602'))))
# Course(program='BCB', designation='2101') CourseInfo(credits='1', terms=('Fall',), prereqs=((('CHEM', '2221'), ('BSCI', '1510')),))
# Course(program='BCB', designation='4320') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHEM', '3710'),),))
# Course(program='BME', designation='3860') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='BME', designation='3861') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='BME', designation='4959') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='BME', designation='4950') CourseInfo(credits='2', terms=('Fall',), prereqs=((('BME', '3100'),),))
# Course(program='BME', designation='2100') CourseInfo(credits='3', terms=('Fall',), prereqs=((('PHYS', '1601'), ('MATH', '1301'), ('CS', '1103')),))
# Course(program='BME', designation='3000') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BME', '2100'), ('MATH', '2400')), (('BME', '2200'), ('MATH', '2400')), (('BME', '2100'), ('MATH', '2420')), (('BME', '2200'), ('MATH', '2420'))))
# Course(program='BME', designation='3100') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CS', '1103'),),))
# Course(program='BME', designation='3110') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('BME', '2100'), ('BME', '3100')),))
# Course(program='BME', designation='3200') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('MATH', '2300'),),))
# Course(program='BME', designation='3890') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BME', designation='4100') CourseInfo(credits='3', terms=('Fall',), prereqs=((('PHYS', '1602'),),))
# Course(program='BME', designation='4200') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='BME', designation='4420') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BME', '4400'), ('CS', '1103')),))
# Course(program='BME', designation='4600') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('BSCI', '1510'), ('CHEM', '1602')),))
# Course(program='BME', designation='4900W') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BME', '3100'),),))
# Course(program='BME', designation='2200') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHEM', '1602'), ('BME', '2100')),))
# Course(program='BME', designation='2210') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('BME', '2100'), ('BSCI', '1510'), ('BSCI', '1510L')),))
# Course(program='BME', designation='3101') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CS', '1103'),),))
# Course(program='BME', designation='3891') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='BME', designation='3892') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='BME', designation='3893') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='BME', designation='4400') CourseInfo(credits='3', terms=('Spring',), prereqs=((('PHYS', '1602'), ('PHYS', '1602L'), ('MATH', '2400')),))
# Course(program='BME', designation='4500') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '1510'), ('BME', '3000')), (('BSCI', '1510'), ('CHBE', '3300')), (('BSCI', '1510'), ('ME', '3224'))))
# Course(program='BME', designation='4951') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BME', '4950'),),))
# Course(program='BME', designation='3300') CourseInfo(credits='4', terms=('Spring', 'Fall'), prereqs=((('EECE', '2213'), ('EECE', '2213L')),))
# Course(program='BNJO', designation='1100') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='BRQ', designation='1100') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSCI', designation='1111') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='BSCI', designation='3850') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSCI', designation='3861') CourseInfo(credits=3, terms=('Summer', 'Spring', 'Fall'), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='3961') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=((('BSCI', '3861'),),))
# Course(program='BSCI', designation='4999') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSCI', designation='1510L') CourseInfo(credits='1', terms=('Fall',), prereqs=((('BSCI', '1510'),),))
# Course(program='BSCI', designation='2201L') CourseInfo(credits='1', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSCI', designation='2210L') CourseInfo(credits='1', terms=('Spring', 'Fall'), prereqs=((('BSCI', '2210'),),))
# Course(program='BSCI', designation='2238L') CourseInfo(credits='1', terms=('Fall',), prereqs=((('BSCI', '2238'),),))
# Course(program='BSCI', designation='3860') CourseInfo(credits='1', terms=('Summer', 'Spring', 'Fall'), prereqs=((('BSCI', '1510'), ('BSCI', '1511')),))
# Course(program='BSCI', designation='1100L') CourseInfo(credits='1', terms=('Summer', 'Spring'), prereqs=())
# Course(program='BSCI', designation='1511L') CourseInfo(credits='1', terms=('Spring',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='1001') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='BSCI', designation='3965') CourseInfo(credits='2', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSCI', designation='1512L') CourseInfo(credits='2', terms=('Spring',), prereqs=((('BSCI', '1511'), ('BSCI', '1510L')),))
# Course(program='BSCI', designation='1510') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CHEM', '1601'),),))
# Course(program='BSCI', designation='2205') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='2210') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='2238') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='2520') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('BSCI', '1510'), ('CHEM', '2212')), (('BSCI', '1510'), ('CHEM', '2222'))))
# Course(program='BSCI', designation='3230') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='3252') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='3254') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='4266') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BSCI', '2210'),),))
# Course(program='BSCI', designation='1100') CourseInfo(credits='3', terms=('Summer', 'Spring'), prereqs=())
# Course(program='BSCI', designation='1511') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '1510'),),))
# Course(program='BSCI', designation='2201') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '1510'),),))
# Course(program='BSCI', designation='3226') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('BSCI', '2201'),), (('BSCI', '2210'),)))
# Course(program='BSCI', designation='3233') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='3234') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='3239') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '1511'), ('BSCI', '2205')),))
# Course(program='BSCI', designation='3245') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='3256') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='3258') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '2201'),), (('BSCI', '2520'),)))
# Course(program='BSCI', designation='3270') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='3890') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='3236') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='3272') CourseInfo(credits='3', terms=('Fall',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='4265') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '2520'),),))
# Course(program='BSCI', designation='3228') CourseInfo(credits='3', terms=('Summer',), prereqs=())
# Course(program='BSCI', designation='1105') CourseInfo(credits='4', terms=('Fall',), prereqs=())
# Course(program='BSCI', designation='1103') CourseInfo(credits='4', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSCI', designation='2219') CourseInfo(credits='4', terms=('Spring',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSCI', designation='2218') CourseInfo(credits='4', terms=('Spring',), prereqs=((('BSCI', '1511'),),))
# Course(program='BSSN', designation='1100') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSSN', designation='1000') CourseInfo(credits='1', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSSN', designation='2100') CourseInfo(credits='2', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSSN', designation='4100') CourseInfo(credits='2', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSSN', designation='2200') CourseInfo(credits='4', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BSSN', designation='4200') CourseInfo(credits='4', terms=('Spring', 'Fall'), prereqs=())
# Course(program='BUS', designation='2100') CourseInfo(credits=3, terms=('Fall',), prereqs=((('ECON', '1020'),),))
# Course(program='BUS', designation='2300') CourseInfo(credits=3, terms=('Fall',), prereqs=((('BUS', '2100'), ('BME', '3200')), (('ECON', '1020'), ('BME', '3200')), (('BUS', '2100'), ('ECON', '1500')), (('ECON', '1020'), ('ECON', '1500')), (('BUS', '2100'), ('ECON', '1510')), (('ECON', '1020'), ('ECON', '1510')), (('BUS', '2100'), ('MATH', '1011')), (('ECON', '1020'), ('MATH', '1011')), (('BUS', '2100'), ('MATH', '2810')), (('ECON', '1020'), ('MATH', '2810')), (('BUS', '2100'), ('MATH', '2820')), (('ECON', '1020'), ('MATH', '2820')), (('BUS', '2100'), ('MATH', '2821')), (('ECON', '1020'), ('MATH', '2821')), (('BUS', '2100'), ('PSY', '2100')), (('ECON', '1020'), ('PSY', '2100')), (('BUS', '2100'), ('PSY-PC', '2110')), (('ECON', '1020'), ('PSY-PC', '2110')), (('BUS', '2100'), ('SOC', '2100')), (('ECON', '1020'), ('SOC', '2100'))))
# Course(program='BUS', designation='2400') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='BUS', designation='2600') CourseInfo(credits=3, terms=('Fall',), prereqs=((('BME', '3200'),), (('ECON', '1500'),), (('ECON', '1510'),), (('MATH', '1011'),), (('MATH', '2810'),), (('MATH', '2820'),), (('MATH', '2821'),), (('PSY', '2100'),), (('PSY-PC', '2110'),), (('SOC', '2100'),)))
# Course(program='BUS', designation='2700') CourseInfo(credits=3, terms=('Fall',), prereqs=((('ECON', '1020'), ('BME', '3200')), (('ECON', '1020'), ('ECON', '1500')), (('ECON', '1020'), ('ECON', '1510')), (('ECON', '1020'), ('MATH', '1011')), (('ECON', '1020'), ('MATH', '2810')), (('ECON', '1020'), ('MATH', '2820')), (('ECON', '1020'), ('MATH', '2821')), (('ECON', '1020'), ('PSY', '2100')), (('ECON', '1020'), ('PSY-PC', '2110')), (('ECON', '1020'), ('SOC', '2100'))))
# Course(program='CE', designation='3841') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='CE', designation='3842') CourseInfo(credits=3, terms=('Fall',), prereqs=((('CE', '3841'),),))
# Course(program='CE', designation='3843') CourseInfo(credits=3, terms=('Spring',), prereqs=((('CE', '3842'),),))
# Course(program='CE', designation='3700L') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='CE', designation='4950') CourseInfo(credits='1', terms=('Fall',), prereqs=((('CE', '3100W'),),))
# Course(program='CE', designation='4900') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='CE', designation='4959') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='CE', designation='2100') CourseInfo(credits='2', terms=('Fall',), prereqs=())
# Course(program='CE', designation='2105') CourseInfo(credits='2', terms=('Spring',), prereqs=((('CE', '2100'),),))
# Course(program='CE', designation='3100W') CourseInfo(credits='2', terms=('Spring',), prereqs=((('CE', '3200'),),))
# Course(program='CE', designation='4951') CourseInfo(credits='2', terms=('Spring',), prereqs=((('CE', '4950'),),))
# Course(program='CE', designation='2200') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='CE', designation='2205') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=((('CE', '2200'),),))
# Course(program='CE', designation='3200') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CE', '2205'),),))
# Course(program='CE', designation='3250') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CE', '2205'),),))
# Course(program='CE', designation='3600') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CHEM', '1601'), ('PHYS', '1601'), ('PHYS', '1602'), ('MATH', '2420')),))
# Course(program='CE', designation='3601') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CE', designation='3700') CourseInfo(credits='3', terms=('Fall',), prereqs=((('ME', '2190'), ('MATH', '2420')),))
# Course(program='CE', designation='4200') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CE', '3205'),),))
# Course(program='CE', designation='4300') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CE', designation='4400') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CE', '3205'),),))
# Course(program='CE', designation='4405') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CE', designation='4510') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CE', '3601'),),))
# Course(program='CE', designation='3205') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CE', '3200'),),))
# Course(program='CE', designation='3705') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHEM', '1601'), ('PHYS', '1601'), ('PHYS', '1602'), ('MATH', '2420'), ('CE', '3700')),))
# Course(program='CE', designation='4210') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CE', '3205'),),))
# Course(program='CE', designation='4250') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CE', '3250'),),))
# Course(program='CE', designation='4420') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CE', '4400'),),))
# Course(program='CE', designation='4425') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='CE', designation='4430') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='CE', designation='4500') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CE', '3601'),),))
# Course(program='CE', designation='4415') CourseInfo(credits='3', terms=('Summer',), prereqs=())
# Course(program='CE', designation='3501') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CE', designation='3890') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='CE', designation='4410') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CE', '4400'),),))
# Course(program='CE', designation='2101') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CE', designation='2120') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CE', designation='4401') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CE', '4400'),),))
# Course(program='CHBE', designation='3860') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='CHBE', designation='3861') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='CHBE', designation='3890') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='CHBE', designation='4959') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='CHBE', designation='2100') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CHBE', designation='2150') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CHEM', '1602'),),))
# Course(program='CHBE', designation='3200') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CHBE', '2200'), ('CHBE', '2250')),))
# Course(program='CHBE', designation='3300') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CHBE', designation='4500') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('BSCI', '1510'), ('CHBE', '3250'), ('CHBE', '3300')), (('CHBE', '2150'), ('CHBE', '3250'), ('CHBE', '3300'))))
# Course(program='CHBE', designation='4870') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CHBE', '2200'),),))
# Course(program='CHBE', designation='4900W') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CHBE', '3250'), ('CHBE', '3900W'), ('CHBE', '3350')),))
# Course(program='CHBE', designation='2200') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='CHBE', designation='2250') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHBE', '2100'),),))
# Course(program='CHBE', designation='3250') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHEM', '2211'), ('CHBE', '3200')), (('CHEM', '2221'), ('CHBE', '3200'))))
# Course(program='CHBE', designation='3350') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHBE', '3300'),),))
# Course(program='CHBE', designation='3600') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHBE', '3200'), ('MATH', '2420')),))
# Course(program='CHBE', designation='4820') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHBE', '2150'),), (('BSCI', '1510'),)))
# Course(program='CHBE', designation='4860') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHEM', '2211'), ('CHBE', '2200')), (('CHEM', '2221'), ('CHBE', '2200'))))
# Course(program='CHBE', designation='4880') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHBE', '3300'),),))
# Course(program='CHBE', designation='4951W') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHBE', '4950W'),),))
# Course(program='CHBE', designation='4810') CourseInfo(credits='3', terms=('Spring',), prereqs=((('BSCI', '1510'),), (('CHBE', '2150'),)))
# Course(program='CHBE', designation='4840') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='CHBE', designation='4830') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CHBE', '3200'), ('CHEM', '3300')),))
# Course(program='CHBE', designation='4850') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CHBE', designation='4950W') CourseInfo(credits='4', terms=('Fall',), prereqs=((('CHBE', '3200'), ('CHBE', '3250'), ('CHBE', '3350')),))
# Course(program='CHBE', designation='3900W') CourseInfo(credits='4', terms=('Spring',), prereqs=((('CHBE', '3200'), ('CHBE', '3300')),))
# Course(program='CHEM', designation='3860') CourseInfo(credits=3, terms=('Summer', 'Spring', 'Fall'), prereqs=())
# Course(program='CHEM', designation='1111') CourseInfo(credits=3, terms=('Spring',), prereqs=())
# Course(program='CHEM', designation='1601L') CourseInfo(credits='1', terms=('Summer', 'Fall'), prereqs=((('CHEM', '1601'),),))
# Course(program='CHEM', designation='2100L') CourseInfo(credits='1', terms=('Fall',), prereqs=((('CHEM', '2100'),),))
# Course(program='CHEM', designation='2221L') CourseInfo(credits='1', terms=('Summer', 'Fall'), prereqs=((('CHEM', '2211'),), (('CHEM', '2221'),)))
# Course(program='CHEM', designation='1010L') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='CHEM', designation='1020L') CourseInfo(credits='1', terms=('Spring', 'Fall'), prereqs=())
# Course(program='CHEM', designation='1602L') CourseInfo(credits='1', terms=('Summer', 'Spring'), prereqs=((('CHEM', '1601L'),),))
# Course(program='CHEM', designation='2222L') CourseInfo(credits='1', terms=('Summer', 'Spring'), prereqs=((('CHEM', '2212'),), (('CHEM', '2222'),)))
# Course(program='CHEM', designation='3315') CourseInfo(credits='1', terms=('Spring',), prereqs=((('CHEM', '2222L'), ('MATH', '1201')), (('CHEM', '2222L'), ('MATH', '1301'))))
# Course(program='CHEM', designation='3600') CourseInfo(credits='1', terms=('Spring',), prereqs=((('CHEM', '2212'),), (('CHEM', '2222'),)))
# Course(program='CHEM', designation='4980') CourseInfo(credits='2', terms=('Spring', 'Fall'), prereqs=())
# Course(program='CHEM', designation='3980') CourseInfo(credits='2', terms=('Spring', 'Fall'), prereqs=())
# Course(program='CHEM', designation='4999') CourseInfo(credits='2', terms=('Spring', 'Fall'), prereqs=())
# Course(program='CHEM', designation='1601') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=())
# Course(program='CHEM', designation='2100') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CHEM', designation='2211') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='CHEM', designation='2221') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=((('CHEM', '1602'),),))
# Course(program='CHEM', designation='2222') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=((('CHEM', '2221'),),))
# Course(program='CHEM', designation='3010') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CHEM', '3300'),), (('CHEM', '3310'),)))
# Course(program='CHEM', designation='3120') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CHEM', '2100'), ('CHEM', '2212')), (('CHEM', '2100'), ('CHEM', '2222'))))
# Course(program='CHEM', designation='3300') CourseInfo(credits='3', terms=('Fall',), prereqs=((('PHYS', '1501'), ('MATH', '1201')), (('PHYS', '1601'), ('MATH', '1201')), (('PHYS', '1901'), ('MATH', '1201')), (('PHYS', '1501'), ('MATH', '1301')), (('PHYS', '1601'), ('MATH', '1301')), (('PHYS', '1901'), ('MATH', '1301'))))
# Course(program='CHEM', designation='4965') CourseInfo(credits='3', terms=('Fall',), prereqs=((('CHEM', '2100'), ('CHEM', '2100L')),))
# Course(program='CHEM', designation='1010') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='CHEM', designation='1020') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='CHEM', designation='1602') CourseInfo(credits='3', terms=('Summer', 'Spring', 'Fall'), prereqs=((('CHEM', '1601'),),))
# Course(program='CHEM', designation='2212') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='CHEM', designation='2610') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHEM', '1602'),),))
# Course(program='CHEM', designation='3135W') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHEM', '2100'), ('CHEM', '2100L')),))
# Course(program='CHEM', designation='3310') CourseInfo(credits='3', terms=('Spring',), prereqs=((('PHYS', '1501'), ('MATH', '1201')), (('PHYS', '1601'), ('MATH', '1201')), (('PHYS', '1901'), ('MATH', '1201')), (('PHYS', '1501'), ('MATH', '1301')), (('PHYS', '1601'), ('MATH', '1301')), (('PHYS', '1901'), ('MATH', '1301'))))
# Course(program='CHEM', designation='3630') CourseInfo(credits='3', terms=('Spring',), prereqs=((('CHEM', '1602'),),))
# Course(program='CHEM', designation='3710') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('CHEM', '2212'),), (('CHEM', '2222'),)))
# ...
# Course(program='SPAN', designation='3830') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3301W'), ('SPAN', '3302')),))
# Course(program='SPAN', designation='4315') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3301W'), ('SPAN', '3302')),))
# Course(program='SPAN', designation='4320') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3301W'), ('SPAN', '3302')),))
# Course(program='SPAN', designation='4340') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3301W'), ('SPAN', '3302')),))
# Course(program='SPAN', designation='4345') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3301W'), ('SPAN', '3302')),))
# Course(program='SPAN', designation='4405') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4420') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4425') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4620') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4670') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4750') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4760') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4998') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPAN', designation='3365') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='3835') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='3893') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4310') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPAN', '3301W'),), (('SPAN', '3302'),)))
# Course(program='SPAN', designation='4335') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPAN', '3301W'),), (('SPAN', '3302'),)))
# Course(program='SPAN', designation='4415') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4450') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4465') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4475') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4550') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4740') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4999') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='SPAN', designation='3325') CourseInfo(credits='3', terms=('Summer',), prereqs=((('SPAN', '3301W'),), (('SPAN', '3302'),)))
# Course(program='SPAN', designation='3330') CourseInfo(credits='3', terms=('Summer',), prereqs=((('SPAN', '3301W'), ('SPAN', '3302')),))
# Course(program='SPAN', designation='3350') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3301W'),), (('SPAN', '3302'),), (('SPAN', '3303'),)))
# Course(program='SPAN', designation='4355') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4640') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4730') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4741') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='3385') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4325') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPAN', '3301W'), ('SPAN', '3302')),))
# Course(program='SPAN', designation='4400') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='4440') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPAN', '3303'),),))
# Course(program='SPAN', designation='1100') CourseInfo(credits='5', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPAN', designation='1101') CourseInfo(credits='5', terms=('Summer', 'Spring', 'Fall'), prereqs=())
# Course(program='SPAN', designation='1102') CourseInfo(credits='5', terms=('Summer', 'Spring', 'Fall'), prereqs=((('SPAN', '1100'),), (('SPAN', '1101'),)))
# Course(program='SPAN', designation='1103') CourseInfo(credits='5', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPAN', designation='2203') CourseInfo(credits='5', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='3690') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='SPED', designation='3890') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='3930') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='2140') CourseInfo(credits=3, terms=('Spring',), prereqs=())
# Course(program='SPED', designation='3240') CourseInfo(credits=3, terms=('Spring',), prereqs=())
# Course(program='SPED', designation='2111') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='2301') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='2331') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='2831') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='2341') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='SPED', designation='2821') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='SPED', designation='3361') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='SPED', designation='1175') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='1001') CourseInfo(credits='1', terms=('Spring',), prereqs=())
# Course(program='SPED', designation='2110') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='2420') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='3016') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='3835') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='2540') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='SPED', designation='2550') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='2860') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='SPED', designation='3301') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='2720') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='3720') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='3740') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='2730') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='3730') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='1210') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='2160') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='2310') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPED', '1210'),),))
# Course(program='SPED', designation='2430') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPED', designation='3332') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPED', designation='4950') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='SPED', designation='3770') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='SPED', designation='2901') CourseInfo(credits='9', terms=('Spring',), prereqs=())
# Course(program='SPED', designation='4951') CourseInfo(credits='9', terms=('Spring',), prereqs=())
# Course(program='SPEDG', designation='3344') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPEDG', designation='3354') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='SPEDG', designation='3871') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='SPEDH', designation='3308') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPED', '1210'),),))
# Course(program='SPEDH', designation='3348') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPEDH', designation='3358') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPED', '1210'),),))
# Course(program='SPEDH', designation='3777') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SPEDH', designation='3871') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPED', '1210'), ('SPED', '2110')),))
# Course(program='SPEDH', designation='3318') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPED', '1210'),),))
# Course(program='SPEDH', designation='3328') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPED', '1210'),),))
# Course(program='SPEDH', designation='3338') CourseInfo(credits='3', terms=('Spring',), prereqs=((('SPED', '1210'),),))
# Course(program='SPEDH', designation='3368') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPEDH', designation='3378') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPEDH', designation='3388') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPEDH', designation='3771') CourseInfo(credits='5', terms=('Fall',), prereqs=())
# Course(program='SPEDS', designation='3312') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPED', '2310'),),))
# Course(program='SPEDS', designation='3330') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPEDS', designation='3350') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPEDS', designation='3661') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPEDS', designation='3667') CourseInfo(credits='3', terms=('Fall',), prereqs=((('SPED', '1210'), ('SPEDS', '3300'), ('SPEDS', '3330'), ('SPEDS', '3312'), ('SPEDS', '3350')),))
# Course(program='SPEDS', designation='3871') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=((('SPED', '1210'), ('SPED', '2110'), ('SPED', '2430')),))
# Course(program='SPEDS', designation='2120') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='SPEDS', designation='2450') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='SPEDS', designation='3300') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='SPEDS', designation='2430') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SPEDV', designation='3305') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='SPEDV', designation='3335') CourseInfo(credits='2', terms=('Fall',), prereqs=())
# Course(program='SPEDV', designation='3315') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SSED', designation='2100') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='SSED', designation='3900') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='SSED', designation='3890') CourseInfo(credits=3, terms=('Summer', 'Spring'), prereqs=())
# Course(program='SSED', designation='3850') CourseInfo(credits=3, terms=('Fall',), prereqs=())
# Course(program='SSED', designation='3371') CourseInfo(credits='1', terms=('Fall',), prereqs=())
# Course(program='SSED', designation='2240') CourseInfo(credits='2', terms=('Spring',), prereqs=())
# Course(program='SSED', designation='3240') CourseInfo(credits='2', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SSED', designation='3260') CourseInfo(credits='3', terms=('Spring', 'Fall'), prereqs=())
# Course(program='SSED', designation='3320') CourseInfo(credits='3', terms=('Fall',), prereqs=())
# Course(program='SSED', designation='4963') CourseInfo(credits='3', terms=('Spring',), prereqs=())
# Course(program='STPN', designation='1100') CourseInfo(credits=3, terms=('Spring', 'Fall'), prereqs=())
# Course(program='STPN', designation='1010') CourseInfo(credits='1', terms=('Spring', 'Fall'), prereqs=())
# Course(program='TBTN', designation='1101') CourseInfo(credits='4', terms=('Fall',), prereqs=())
# Course(program='TBTN', designation='1102') CourseInfo(credits='4', terms=('Spring',), prereqs=((('TBTN', '1101'),),))
# Course(program='TBTN', designation='2201') CourseInfo(credits='4', terms=('Fall',), prereqs=())
# CourseInfo(credits='0', terms=('Spring', 'Fall'), prereqs=((('BASS', '1000'),), (('BSSN', '1000'),), (('CLAR', '1000'),), (('CLLO', '1000'),), (('COMP', '1000'),), (('FLUT', '1000'),), (('GTR', '1000'),), (('HARP', '1000'),), (('HORN', '1000'),), (('MUSO', '1000'),), (('OBOE', '1000'),), (('PERC', '1000'),), (('PIAN', '1000'),), (('SAX', '1000'),), (('AADS', '1001'),), (('ANTH', '1001'),), (('ARTS', '1001'),), (('ASTR', '1001'),), (('BSCI', '1001'),), (('CMST', '1001'),), (('EDUC', '1001'),), (('EES', '1001'),), (('ES', '1001'),), (('EUS', '1001'),), (('ITA', '1001'),), (('MGRL', '1001'),), (('MHS', '1001'),), (('MUSO', '1001'),), (('NSC', '1001'),), (('PSCI', '1001'),), (('PSY', '1001'),), (('RLST', '1001'),), (('SOC', '1001'),), (('SPAN', '1001'),), (('SPED', '1001'),), (('AMER', '1002'),), (('CMST', '1002'),), (('PHIL', '1002'),), (('AMER', '1002W'),), (('CMA', '1002W'),), (('JS', '1002W'),), (('PHIL', '1002W'),), (('PHIL', '1003'),), (('MATH', '1005'),), (('PHIL', '1005'),), (('PHIL', '1008'),), (('PHIL', '1008W'),), (('AADS', '1010'),), (('ASTR', '1010'),), (('CHEM', '1010'),), (('CLAS', '1010'),), (('ECON', '1010'),), (('GTR', '1010'),), (('MATH', '1010'),), (('MUED', '1010'),), (('MUSE', '1010'),), (('PERC', '1010'),), (('PHYS', '1010'),), (('PIAN', '1010'),), (('RLST', '1010'),), (('SOC', '1010'),), (('STPN', '1010'),), (('SOC', '1010W'),), (('CHIN', '1011'),), (('JAPN', '1011'),), (('MATH', '1011'),), (('CHIN', '1012'),), (('JAPN', '1012'),), (('AADS', '1016'),), (('CHEM', '1020'),), (('ECON', '1020'),), (('GTR', '1020'),), (('MUED', '1020'),), (('MUSE', '1020'),), (('PIAN', '1020'),), (('SOC', '1020'),), (('ASTR', '1020L'),), (('CHEM', '1020L'),), (('SOC', '1020W'),), (('EES', '1030'),), (('GTR', '1030'),), (('MUED', '1030'),), (('MUSE', '1030'),), (('EES', '1030L'),), (('MUED', '1040'),), (('SOC', '1041'),), (('SOC', '1041W'),), (('MUED', '1050'),), (('HIST', '1060'),), (('MUED', '1060'),), (('HIST', '1070'),), (('MUED', '1070'),), (('EES', '1080'),), (('HIST', '1080'),), (('HIST', '1090'),), (('BASS', '1100'),), (('BNJO', '1100'),), (('BRQ', '1100'),), (('BSCI', '1100'),), (('BSSN', '1100'),), (('CLAR', '1100'),), (('CLLO', '1100'),), (('COMP', '1100'),), (('DRUM', '1100'),), (('ENGL', '1100'),), (('EUPH', '1100'),), (('FDDL', '1100'),), (('FLUT', '1100'),), (('GTR', '1100'),), (('HARP', '1100'),), (('HART', '1100'),), (('HORN', '1100'),), (('HRPS', '1100'),), (('JAZZ', '1100'),), (('MATH', '1100'),), (('MGRL', '1100'),), (('MNDL', '1100'),), (('MUSL', '1100'),), (('NS', '1100'),), (('OBOE', '1100'),), (('ORGN', '1100'),), (('PERC', '1100'),), (('PHIL', '1100'),), (('PIAN', '1100'),), (('PSCI', '1100'),), (('RLST', '1100'),), (('SAX', '1100'),), (('SPAN', '1100'),), (('STPN', '1100'),)))

# %% [markdown]
# ## Testing Scheduler Functionality
